# %%
# !pip install llama-index-core
# !pip install llama-index-llms-openai
# !pip install llama-index-llms-replicate
# !pip install llama-index-embeddings-huggingface
# Out:
# Requirement already satisfied: llama-index-core in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.12.15)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (3.11.11)
# Requirement already satisfied: dataclasses-json in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (2024.12.0)
# Requirement already satisfied: httpx in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (3.1)
# Requirement already satisfied: nltk>3.8.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (1.24.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (0.3.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.18.3)
# Requirement already satisfied: click in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core) (8.1.8)
# Requirement already satisfied: joblib in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core) (2023.3.23)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.8.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.8.0->llama-index-core) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.1.1)
# Requirement already satisfied: colorama in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json->llama-index-core) (3.26.0)
# Requirement already satisfied: anyio in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (23.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx->llama-index-core) (1.3.0)
# Requirement already satisfied: llama-index-llms-openai in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.1.31)
# Collecting llama-index-core<0.11.0,>=0.10.57 (from llama-index-llms-openai)
#   Using cached llama_index_core-0.10.68.post1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-llms-openai) (1.60.2)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (3.11.11)
# Requirement already satisfied: dataclasses-json in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2024.12.0)
# Requirement already satisfied: httpx in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (3.1)
# Requirement already satisfied: nltk!=3.9,>=3.8.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.24.2)
# Requirement already satisfied: pandas in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (9.5.0)
# Requirement already satisfied: pydantic<3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (0.3.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.17.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (0.8.2)
# Requirement already satisfied: sniffio in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (3.4)
# Requirement already satisfied: certifi in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (8.1.8)
# Requirement already satisfied: joblib in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2023.3.23)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.26.15)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: colorama in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (3.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (2024.2)
# Requirement already satisfied: packaging>=17.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (23.1)
# Requirement already satisfied: six>=1.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.57->llama-index-llms-openai) (1.16.0)
# Using cached llama_index_core-0.10.68.post1-py3-none-any.whl (1.6 MB)
# Installing collected packages: llama-index-core
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.12.15
#     Uninstalling llama-index-core-0.12.15:
#       Successfully uninstalled llama-index-core-0.12.15
# Successfully installed llama-index-core-0.10.68.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-cli 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-cli 0.4.0 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-embeddings-huggingface 0.5.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-embeddings-openai 0.3.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-indices-managed-llama-cloud 0.6.4 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-llms-replicate 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-multi-modal-llms-openai 0.4.2 requires llama-index-core<0.13.0,>=0.12.3, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-multi-modal-llms-openai 0.4.2 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-agent-openai<0.5.0,>=0.4.0, but you have llama-index-agent-openai 0.2.9 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-question-gen-openai 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-question-gen-openai 0.3.0 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-readers-file 0.4.4 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-readers-llama-parse 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-parse 0.5.20 requires llama-index-core>=0.11.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# Requirement already satisfied: llama-index-llms-replicate in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.4.0)
# Collecting llama-index-core<0.13.0,>=0.12.0 (from llama-index-llms-replicate)
#   Using cached llama_index_core-0.12.15-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (3.11.11)
# Requirement already satisfied: dataclasses-json in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (2024.12.0)
# Requirement already satisfied: httpx in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (3.1)
# Requirement already satisfied: nltk>3.8.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (3.9.1)
# Requirement already satisfied: numpy in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.24.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (0.3.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.18.3)
# Requirement already satisfied: click in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (8.1.8)
# Requirement already satisfied: joblib in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (2023.3.23)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (3.1.1)
# Requirement already satisfied: colorama in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (3.26.0)
# Requirement already satisfied: anyio in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (23.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-replicate) (1.3.0)
# Using cached llama_index_core-0.12.15-py3-none-any.whl (1.6 MB)
# Installing collected packages: llama-index-core
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.10.68.post1
#     Uninstalling llama-index-core-0.10.68.post1:
#       Successfully uninstalled llama-index-core-0.10.68.post1
# Successfully installed llama-index-core-0.12.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-agents 0.0.14 requires llama-index-core<0.11.0,>=0.10.50, but you have llama-index-core 0.12.15 which is incompatible.
# llama-index-agent-openai 0.2.9 requires llama-index-core<0.11.0,>=0.10.41, but you have llama-index-core 0.12.15 which is incompatible.
# llama-index-cli 0.4.0 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-llms-openai 0.1.31 requires llama-index-core<0.11.0,>=0.10.57, but you have llama-index-core 0.12.15 which is incompatible.
# llama-index-multi-modal-llms-openai 0.4.2 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-agent-openai<0.5.0,>=0.4.0, but you have llama-index-agent-openai 0.2.9 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-question-gen-openai 0.3.0 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# Requirement already satisfied: llama-index-embeddings-huggingface in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.5.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-embeddings-huggingface) (0.12.15)
# Requirement already satisfied: sentence-transformers>=2.6.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-embeddings-huggingface) (3.4.1)
# Requirement already satisfied: filelock in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.12.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.11.11)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.0.37)
# Requirement already satisfied: dataclasses-json in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: httpx in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.1)
# Requirement already satisfied: nltk>3.8.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: numpy in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.24.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (9.5.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.10.6)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.3.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.17.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.48.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.0.0)
# Requirement already satisfied: scikit-learn in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.2)
# Requirement already satisfied: scipy in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.18.3)
# Requirement already satisfied: click in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (8.1.8)
# Requirement already satisfied: joblib in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2023.3.23)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.1.1)
# Requirement already satisfied: sympy in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.2)
# Requirement already satisfied: colorama in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.4.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.5.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.26.0)
# Requirement already satisfied: anyio in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)

# %%
# !pip install llama-agents llama-index-agent-openai
# Out:
# Requirement already satisfied: llama-agents in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.0.14)
# Requirement already satisfied: llama-index-agent-openai in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.2.9)
# Requirement already satisfied: fastapi<0.110.0,>=0.109.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-agents) (0.109.2)
# Collecting llama-index-core<0.11.0,>=0.10.50 (from llama-agents)
#   Using cached llama_index_core-0.10.68.post1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pytest-asyncio<0.24.0,>=0.23.7 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-agents) (0.23.8)
# Requirement already satisfied: pytest-mock<4.0.0,>=3.14.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-agents) (3.14.0)
# Requirement already satisfied: textual<0.71.0,>=0.70.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-agents) (0.70.0)
# Requirement already satisfied: uvicorn<0.31.0,>=0.30.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-agents) (0.30.6)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-agent-openai) (0.1.31)
# Requirement already satisfied: openai>=1.14.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-agent-openai) (1.60.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastapi<0.110.0,>=0.109.1->llama-agents) (2.10.6)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastapi<0.110.0,>=0.109.1->llama-agents) (0.36.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastapi<0.110.0,>=0.109.1->llama-agents) (4.12.2)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.50->llama-agents) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (3.11.11)
# Requirement already satisfied: dataclasses-json in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (2024.12.0)
# Requirement already satisfied: httpx in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (3.1)
# Requirement already satisfied: nltk!=3.9,>=3.8.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.24.2)
# Requirement already satisfied: pandas in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (2.2.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (9.5.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (0.3.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (4.67.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.17.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.14.0->llama-index-agent-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.14.0->llama-index-agent-openai) (0.8.2)
# Requirement already satisfied: sniffio in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.3.0)
# Requirement already satisfied: pytest<9,>=7.0.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pytest-asyncio<0.24.0,>=0.23.7->llama-agents) (7.3.1)
# Requirement already satisfied: markdown-it-py>=2.1.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual<0.71.0,>=0.70.0->llama-agents) (3.0.0)
# Requirement already satisfied: rich>=13.3.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from textual<0.71.0,>=0.70.0->llama-agents) (13.9.4)
# Requirement already satisfied: click>=7.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn<0.31.0,>=0.30.1->llama-agents) (8.1.8)
# Requirement already satisfied: h11>=0.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn<0.31.0,>=0.30.1->llama-agents) (0.14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.50->llama-agents) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.50->llama-agents) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.50->llama-agents) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.50->llama-agents) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.18.3)
# Requirement already satisfied: idna>=2.8 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai) (3.4)
# Requirement already satisfied: colorama in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=7.0->uvicorn<0.31.0,>=0.30.1->llama-agents) (0.4.6)
# Requirement already satisfied: certifi in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.50->llama-agents) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.0.7)
# Requirement already satisfied: mdurl~=0.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.1.0->markdown-it-py[linkify,plugins]>=2.1.0->textual<0.71.0,>=0.70.0->llama-agents) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual<0.71.0,>=0.70.0->llama-agents) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual<0.71.0,>=0.70.0->llama-agents) (0.4.2)
# Requirement already satisfied: joblib in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk!=3.9,>=3.8.1->llama-index-core<0.11.0,>=0.10.50->llama-agents) (2023.3.23)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<0.110.0,>=0.109.1->llama-agents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<0.110.0,>=0.109.1->llama-agents) (2.27.2)
# Requirement already satisfied: iniconfig in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pytest<9,>=7.0.0->pytest-asyncio<0.24.0,>=0.23.7->llama-agents) (2.0.0)
# Requirement already satisfied: packaging in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pytest<9,>=7.0.0->pytest-asyncio<0.24.0,>=0.23.7->llama-agents) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pytest<9,>=7.0.0->pytest-asyncio<0.24.0,>=0.23.7->llama-agents) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.50->llama-agents) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.26.15)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=13.3.3->textual<0.71.0,>=0.70.0->llama-agents) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.50->llama-agents) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.50->llama-agents) (3.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.50->llama-agents) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.50->llama-agents) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.50->llama-agents) (2024.2)
# Requirement already satisfied: uc-micro-py in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual<0.71.0,>=0.70.0->llama-agents) (1.0.3)
# Requirement already satisfied: six>=1.5 in c:\users\retir\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.50->llama-agents) (1.16.0)
# Using cached llama_index_core-0.10.68.post1-py3-none-any.whl (1.6 MB)
# Installing collected packages: llama-index-core
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.12.15
#     Uninstalling llama-index-core-0.12.15:
#       Successfully uninstalled llama-index-core-0.12.15
# Successfully installed llama-index-core-0.10.68.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-cli 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-cli 0.4.0 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-embeddings-huggingface 0.5.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-embeddings-openai 0.3.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-indices-managed-llama-cloud 0.6.4 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-llms-replicate 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-multi-modal-llms-openai 0.4.2 requires llama-index-core<0.13.0,>=0.12.3, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-multi-modal-llms-openai 0.4.2 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-agent-openai<0.5.0,>=0.4.0, but you have llama-index-agent-openai 0.2.9 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-question-gen-openai 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-question-gen-openai 0.3.0 requires llama-index-llms-openai<0.4.0,>=0.3.0, but you have llama-index-llms-openai 0.1.31 which is incompatible.
# llama-index-readers-file 0.4.4 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-index-readers-llama-parse 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.10.68.post1 which is incompatible.
# llama-parse 0.5.20 requires llama-index-core>=0.11.0, but you have llama-index-core 0.10.68.post1 which is incompatible.

# %%
import os
from dotenv import load_dotenv
import numpy as np
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
from scipy.optimize import curve_fit
from scipy.optimize import fsolve
from llama_agents import (
    AgentService,
    HumanService,
    AgentOrchestrator,
    CallableMessageConsumer,
    ControlPlaneServer,
    ServerLauncher,
    SimpleMessageQueue,
    QueueMessage,
)
from llama_index.core.agent import FunctionCallingAgentWorker
from llama_index.core.tools import FunctionTool
from llama_index.llms.openai import OpenAI

#Load environment variables from .env file
load_dotenv()
load_dotenv()
API_KEY = int(x)
os.environ['OPENAI_API_KEY'] = API_KEY

def StockAns (stock: str) -> str :
    # Ticker del activo
    activo = str(stock)  # Ticker del activo
    datos = yf.Ticker(activo).history(period= 'max')

    # 2. Calcular los retornos promedio (Average) y la desviación estándar (std)
    datos['Average'] = datos[['High', 'Low']].mean(axis=1).pct_change()
    datos['std'] = datos['Average'].rolling(window=5).std()

    # Eliminar valores NaN para los ajustes
    datos.dropna(inplace=True)
    
    #Función para empezar analisis de datos sobre la acción solicitada
    def Model_Po_Ex (stock): 
    #This function generate the answer to the question "What is the risk and return of stock x?"
     # 1. Descargar datos históricos del activo
        try: 
            #filtrar datos
            datos_filtrados = datos[datos['Average'] > 0]

            # --- MODELO POLINOMIAL ---
            # Ajustar un modelo polinomial de grado 2
            X_poly = np.column_stack((datos['Average'], datos['Average']**2))  # [x, x^2]
            X_poly = sm.add_constant(X_poly)  # Añadir intercepto
            modelo_poly = sm.OLS(datos['std'], X_poly).fit()

            # Coeficientes del modelo polinomial
            alpha_poly = modelo_poly.params[0]
            beta_1_poly = modelo_poly.params[1]
            beta_2_poly = modelo_poly.params[2]

            # Predicciones del modelo polinomial
            datos['std_pred_poly'] = alpha_poly + beta_1_poly * datos['Average'] + beta_2_poly * datos['Average']**2

            # --- MODELO EXPONENCIAL ---
            # Definir la función exponencial
            def modelo_exponencial(x, alpha, beta):
                    return alpha * np.exp(beta * x)
            # Ajustar el modelo exponencial
            popt, _ = curve_fit(modelo_exponencial, datos['Average'], datos['std'], maxfev=10000)
            alpha_exp, beta_exp = popt

            # Predicciones del modelo exponencial
            datos['std_pred_exp'] = modelo_exponencial(datos['Average'], alpha_exp, beta_exp)

            # Crear un diccionario con los datos
            data1 = { 'Average': datos['Average'].tolist(), 
                    'std_pred_poly': datos['std_pred_poly'].tolist(), 
                    'std_pred_exp': datos['std_pred_exp'].tolist()}

            # Función para encontrar la intersección entre dos funciones
            def interseccion(x):
                std_poly = alpha_poly + beta_1_poly * x + beta_2_poly * x**2
                std_exp = alpha_exp * np.exp(beta_exp * x)
                return std_poly - std_exp

            # Valores iniciales para buscar las raíces
            valores_iniciales = [-0.05, 0.05]  # Suponiendo dos intersecciones

            # Resolver las raíces
            intersecciones = [fsolve(interseccion, x0)[0] for x0 in valores_iniciales]

            # Calcular las desviaciones estándar en las intersecciones
            resultados = [(x, alpha_poly + beta_1_poly * x + beta_2_poly * x**2) for x in intersecciones]

            # Mostrar los resultados
            Intersección = {}
            for i, (x, y) in enumerate(resultados):
                Intersección = {'Average': f"{x:.4f}", 'Risk': f"{y:.4f}"}
                # Crear un diccionario con las intersecciones
                intersecciones_dict = {
                    'Average': [x for x, y in resultados],
                    'Risk': [y for x, y in resultados]
                    }
            return intersecciones_dict
        except ValueError as e:
            return "Error en la ejecución de la función" + str(e)

    def Model_Po_Ex_2(stock):
        try:
            # --- MODELO POLINOMIAL ---
            # Ajustar un modelo polinomial de grado 2
            X_poly = np.column_stack((datos['Average'], datos['Average']**2))  # [x, x^2]
            X_poly = sm.add_constant(X_poly)  # Añadir intercepto
            modelo_poly = sm.OLS(datos['std'], X_poly).fit()

            # Coeficientes del modelo polinomial
            alpha_poly = modelo_poly.params[0]
            beta_1_poly = modelo_poly.params[1]
            beta_2_poly = modelo_poly.params[2]

            # Predicciones del modelo polinomial
            datos['std_pred_poly'] = alpha_poly + beta_1_poly * datos['Average'] + beta_2_poly * datos['Average']**2

            # --- MODELO EXPONENCIAL DE GRADO 2 ---
            # Definir la función exponencial de grado 2
            def modelo_exponencial_grado2(x, alpha, beta1, beta2):
                return alpha * np.exp(beta1 * x + beta2 * x**2)

            # Ajustar el modelo exponencial de grado 2
            popt, _ = curve_fit(modelo_exponencial_grado2, datos['Average'], datos['std'], maxfev=10000)
            alpha_exp2, beta1_exp2, beta2_exp2 = popt

            # Predicciones del modelo exponencial de grado 2
            datos['std_pred_exp2'] = modelo_exponencial_grado2(datos['Average'], alpha_exp2, beta1_exp2, beta2_exp2)

            # Función para encontrar la intersección entre dos funciones
            def interseccion(x):
                std_poly = alpha_poly + beta_1_poly * x + beta_2_poly * x**2
                std_exp2 = alpha_exp2 * np.exp(beta1_exp2 * x + beta2_exp2 * x**2)
                return std_poly - std_exp2

            # Valores iniciales para buscar las raíces
            valores_iniciales_2g = [-0.05, 0.05]  # Suponiendo dos intersecciones

            # Resolver las raíces
            intersecciones_2g = [fsolve(interseccion, x0)[0] for x0 in valores_iniciales_2g]
            # Calcular las desviaciones estándar en las intersecciones
            resultados_2g = [(x, alpha_poly + beta_1_poly * x + beta_2_poly * x**2) for x in intersecciones_2g]

            # Mostrar los resultados
            Intersección_2g = {}
            for i, (x, y) in enumerate(resultados_2g):
                    Intersección_2g = {'Average': f"{x:.4f}", 'Risk': f"{y:.4f}"}
            # Crear un diccionario con las intersecciones
            intersecciones_dict2g = {
                 'Average': [x for x, y in resultados_2g],
                 'Risk': [y for x, y in resultados_2g]
                }
            #Mostrar resultados
            return intersecciones_dict2g
        except ValueError as e:
                return "Error en la ejecución de la función" + str(e)
    def Model_log(stock):

        try:
            #Modelo 3
            #Convertir a logaritmos los datos de std
            datos['log_std'] = np.log(datos['std'])
            datos['log_Average'] = np.log(datos['Average'].replace(0, np.nan).dropna())
            # --- MODELO EXPONENCIAL CON LOGARITMOS ---

            # Ajustar el modelo exponencial transformado con logaritmos
            X_exp_log = sm.add_constant(datos['Average'])  # Log(σ) = Log(α) + β * Average
            modelo_exp_log = sm.OLS(datos['log_std'], X_exp_log).fit()

            # Coeficientes del modelo exponencial con logaritmos
            beta_exp_log = modelo_exp_log.params[1]

            # Predicciones del modelo exponencial con logaritmos
            datos['log_std_pred_exp'] = modelo_exp_log.params[0] + beta_exp_log * datos['Average']

            # Generar valores de x
            x_vals = np.linspace(datos['Average'].min(), datos['Average'].max(), 500)

            # Calcular valores de y para el modelo exponencial con logaritmos
            log_std_pred_exp = modelo_exp_log.params[0] + beta_exp_log * x_vals
            std_pred_exp = np.exp(log_std_pred_exp)  # Transformación inversa para obtener valores positivos

            # Filtrar valores de x y y que no superen el rango de 0.025 y sean positivos
            rango_mask_exp_log = (std_pred_exp > 0) & (std_pred_exp <= 0.0455)

            # Crear diccionario con los datos filtrados
            datos_filtrados = {
                'Average': x_vals[rango_mask_exp_log],
                'Risk': std_pred_exp[rango_mask_exp_log]
                }

                # Convertir a DataFrame
            df_filtrado = pd.DataFrame(datos_filtrados)

                # Calcular máximos y mínimos, acotación de la ecuación.
            max_average = df_filtrado['Average'].max()
            min_average = df_filtrado['Average'].min()
            max_risk = df_filtrado['Risk'].max()
            min_risk = df_filtrado['Risk'].min()

            # Mostrar resultados
            # Crear diccionario con los resultados
            resultados_log = {
                'Average': [max_average,min_average],
                'Risk': [max_risk, min_risk]
                }
            return resultados_log
        except ValueError as e:
            return "Error en la ejecución del modelo: " + str(e)
    # Comparar los modelos y mostrar el mejor resultado
    def compare_models():
        try:
            # Ejecutar los modelos y capturar sus resultados
            print("Ejecutando Model_Po_Ex...")
            print("\nEjecutando Model_Po_Ex_2...")
            print("\nEjecutando Model_log...")
            print("Generando resultados...")

            #Ver los resultados de los modelos ejecutados
            resultados_modelo_1 = Model_Po_Ex(stock)
            resultados_modelo_2 = Model_Po_Ex_2(stock)
            resultados_modelo_3 = Model_log(stock)

            #Convertir los modelos ejecutados en dataframe para procesarlos
            modelo_1 = pd.DataFrame(resultados_modelo_1)
            modelo_2 = pd.DataFrame(resultados_modelo_2)
            modelo_3 = pd.DataFrame(resultados_modelo_3)

           #Clasificar y especificar los valores de los 3 dataframe
           #Clasificación de variable del modelo 1
            return_op_model_1 = modelo_1

            #datax1_return_model_1_Av = return_op_model_1.iloc[0,0] #X1 Average de modelo 1 (X1-1)
            #datax2_return_model_1_Av = return_op_model_1.iloc[1,0] #X2 Average de modelo 1 (X2-1)
            #datay1_return_model_1_Risk = return_op_model_1.iloc[0,1] #Y1 Risk de modelo 1 (Y1-1)
            #datay2_return_model_1_Risk = return_op_model_1.iloc[1,1] #Y2 Risk de modelo 1 (Y2-1)

            #Clasificación de variable del modelo 2
            return_op_model_2 = modelo_2

            #datax1_return_model_2_Av = return_op_model_2.iloc[0,0] #X1 Average de modelo 2 (X1-2)
            #datax2_return_model_2_Av = return_op_model_2.iloc[1,0] #X2 Average de modelo 2 (X2-2)
            #datay1_return_model_2_Risk = return_op_model_2.iloc[0,1] #Y1 Risk de modelo 2 (Y1-2)
            #datay2_return_model_2_Risk = return_op_model_2.iloc[1,1] #Y2 Risk de modelo 2 (Y2-2)

            #Clasificación de variable del modelo 3       
            return_op_model_3 = modelo_3

            #datax1_return_model_3_Av = return_op_model_3.iloc[0,0] #X1 Average de modelo 3 (X1-3)
            #datax2_return_model_3_Av = return_op_model_3.iloc[1,0] #X2 Average de modelo 3 (X2-3)
            #datay1_return_model_3_Risk = return_op_model_3.iloc[0,1] #Y1 Average de modelo 3 (Y1-3)
            #datay2_return_model_3_Risk = return_op_model_3.iloc[1,1] #Y2 Average de modelo 3 (Y2-3)


            #Clasificación de comparación de datos

            # X1-1 > X2-1
            # X1-1 < X2-1
            def CC_Data_1 (return_op_model_1):
                if return_op_model_1.iloc[0,0] > return_op_model_1.iloc[1,0]:
                    BM1_1 = return_op_model_1.iloc[0,0]
                    return BM1_1
                elif return_op_model_1.iloc[0,0] < return_op_model_1.iloc[1,0]:
                    BM2_1 = return_op_model_1.iloc[1,0]
                    return BM2_1
                #En caso de igualdad, poco probable
                else:
                    return (BM1_1 or BM2_1)
                
            #X1-2 > X2-2
            #X1-2 < x2-2
            def CC_Data_2(return_op_model_2):
                if return_op_model_2.iloc[0,0] > return_op_model_2.iloc[1,0]:
                    BM1_2 = return_op_model_2.iloc[0,0]
                    return BM1_2
                elif return_op_model_2.iloc[0,0] < return_op_model_2.iloc[1,0]:
                    BM2_2 = return_op_model_2.iloc[1,0]
                    return BM2_2
                #En caso de igualdad, poco probable
                else:
                    return (BM1_2 or BM2_2)
                
            #X1-3 > X2-3
            #X1-3 < x2-3
            def CC_Data_3(return_op_model_3):
                if return_op_model_3.iloc[0,0] > return_op_model_3.iloc[1,0]:
                    BM1_3 = return_op_model_3.iloc[0,0]
                    return BM1_3
                elif return_op_model_3.iloc[0,0] < return_op_model_3.iloc[1,0]:
                    BM2_3 = return_op_model_3.iloc[1,0]
                    return BM2_3
                #En caso de igualdad, poco probable
                else:
                    return (BM1_3 or BM2_3)
                
            #De los resultados de las anteriores funciones, se hace el ultimo proceso para sacar el mejor rendimiento
            def CC_Data():
                #Primera comparación
                def FCC_Data():
                    if CC_Data_1(return_op_model_1) > CC_Data_2(return_op_model_2):
                        BFCM1 = CC_Data_1(return_op_model_1)
                        return BFCM1
                    elif CC_Data_1(return_op_model_1) < CC_Data_2(return_op_model_2):
                        BFCM2 = CC_Data_2(return_op_model_2)
                        return BFCM2
                    #En caso de igualdad, poco probable
                    else:
                        return (BFCM1 or BFCM2)
                def SCC_Data():
                    if FCC_Data() > CC_Data_3(return_op_model_3):
                        BSCM1 = FCC_Data()
                        return BSCM1
                    elif FCC_Data() < CC_Data_3(return_op_model_3):
                        BSCM2 = CC_Data_3(return_op_model_3)
                        return BSCM2 
                    #En caso de igualdad, poco probable 
                    else:
                        return (BSCM1 or BSCM2)
                return SCC_Data()
            
            def EV_Data():
                def EVC_Data():
                    if CC_Data() == CC_Data_1(return_op_model_1):
                        data_1 = CC_Data_1(return_op_model_1)
                        BM1_1 = return_op_model_1.iloc[0,0]
                        BM2_1 = return_op_model_1.iloc[1,0]
                        data_1 == BM1_1 or data_1 == BM2_1
                        return data_1
                    elif CC_Data() == CC_Data_2(return_op_model_2):
                        data_2 = CC_Data_2(return_op_model_2)
                        BM1_2 = return_op_model_2.iloc[0,0]
                        BM2_2 = return_op_model_2.iloc[1,0]
                        data_2 == BM1_2 or data_2 == BM2_2
                        return data_2
                    else:
                        data_3 = CC_Data_3(return_op_model_3)
                        BM1_3 = return_op_model_3.iloc[0,0]
                        BM2_3 = return_op_model_3.iloc[1,0]
                        data_3 == BM1_3 or data_3 == BM2_3
                        return data_3
                    
                def EVCR_data(): #Busqueda de la variable del mejor resultado en los modelos 

                    def EVCRM1_data():#Busqueda en el primer modelo
                        if EVC_Data() == return_op_model_1.iloc[0,0]: #X1-1 (Primera variable del primer modelo)
                            YM1_1 = return_op_model_1.iloc[0,1] #Prueba de Y1-1
                            return YM1_1
                        elif EVC_Data() == return_op_model_1.iloc[1,0]: #X2-1 (segundavariable del primer modelo)
                            YM2_1 = return_op_model_1.iloc[1,1] #Prueba de Y2-1
                            return YM2_1
                        else: 
                            print("Error en encontrar el riesgo para el rendimiento asociado")       
                    def EVCRM2_data(): #Busqueda en el segundo modelo
                        if EVC_Data() == return_op_model_2.iloc[0,0]: #X1-2 (Primera variable del segundo modelo)
                            YM1_2 = return_op_model_2.iloc[0,1] #Prueba de Y1-2
                            return YM1_2
                        elif EVC_Data() == return_op_model_2.iloc[1,0]: #X2-2 (Segunda variable del segundo modelo)
                            YM2_2 = return_op_model_2.iloc[1,1] #Prueba de Y2-2
                            return YM2_2
                        else: 
                            print("Error en encontrar el riesgo para el rendimiento asociado")
                    def EVCRM3_data(): #Busqueda de la variable del mejor resultado
                        if EVC_Data() == return_op_model_3.iloc[0,0]: #X1-3 (Primera variable del tercer modelo)
                            YM1_3 = return_op_model_3.iloc[0,1] #Prueba de Y1-3
                            return YM1_3
                        elif EVC_Data() == return_op_model_3.iloc[1,0]: #X2-3 (Segunda variable del tercer modelo)
                            YM2_3 = return_op_model_3.iloc[1,1] #Prueba de Y2-3
                            return YM2_3
                        else: 
                            print("Error en encontrar el riesgo para el rendimiento asociado")
                    return EVCRM3_data()  
                return print("El rendimiento asociado a la acción es la siguiete",EVC_Data(), "El riesgo asociado a la acción es la siguiente",EVCR_data())
            return EV_Data()
        except Exception as e:
            print("Error al comparar los modelos: " + str(e))
    return compare_models()

#Crear herramientas de las funciones
Financial_Analysis_tool = FunctionTool.from_defaults(fn=StockAns)

#Crear workers y agentes
Worker1 = FunctionCallingAgentWorker.from_tools({Financial_Analysis_tool})
Agent1 = Worker1.as_agent()

#Crear nuestro multiagente framework components
message_queue = SimpleMessageQueue()
queue_client = message_queue.client

control_plane = ControlPlaneServer(
    message_queue=queue_client,
    orchestrator = AgentOrchestrator(llm=OpenAI(api_key=API_KEY)),
)
Agent_server_1 = AgentService(
    agent=Agent1,
    message_queue=queue_client,
    description="Brinda información sobre los activos, sus rendimientos y riesgos de inversión.",
    service_name="Financial_Analysis_Agent",
    host="127.0.0.1",
    port=8002,
)
human_service=HumanService(
    message_queue=queue_client,
    description="Respuestas a preguntas generales",
    host="127.0.0.1",
    port=8003,
)
#Human Consumer Adicional
def handle_result(message:QueueMessage) -> None:
    print("Resultado:", message.data)

human_consumer = CallableMessageConsumer(handler=handle_result, message_type="human")

#Lanzar los servers
launcher = ServerLauncher(
    [Agent_server_1, human_service],
    control_plane,
    message_queue,
    additional_consumers=[human_consumer],
)
import nest_asyncio
import asyncio

nest_asyncio.apply()
await launcher.launch_servers()
# Out:
# INFO:llama_agents.message_queues.simple - Launching message queue server at 127.0.0.1:8001
# INFO:     Started server process [16916]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 10048] error while attempting to bind on address ('127.0.0.1', 8001): solo se permite un uso de cada dirección de socket (protocolo/dirección de red/puerto)
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
# Out:
# ^C
